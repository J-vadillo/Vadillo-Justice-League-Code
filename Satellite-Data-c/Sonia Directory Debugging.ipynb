# %%
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('/home/vadilloj/MAP2023/Vadillo-Justice-League-Code')

# %%
from Runnable_Modules import Base as base, TrackingUtils as tracking

# %%
simulations = base.get_chars("sims")

# %%
simulations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 simulations
#
# NameError: name 'simulations' is not defined

# %%
s, h1, h = base.load_in_sim("Sandra", return_h = True)

# %%
tracked_filepath = "/home/christenc/Code/python/Justice_League_Code/Data/tracked_particles.hdf5"
tracked_particles = pd.read_hdf(tracked_filepath, key = halo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 tracked_filepath = "/home/christenc/Code/python/Justice_League_Code/Data/tracked_particles.hdf5"
# ----> 2 tracked_particles = pd.read_hdf(tracked_filepath, key = halo)
#
# NameError: name 'halo' is not defined

# %%
simulations.at['Sandra', 'Halo keys']
# Out:
# [np.str_('h148_2'),
#  np.str_('h148_3'),
#  np.str_('h148_4'),
#  np.str_('h148_6'),
#  np.str_('h148_7'),
#  np.str_('h148_10'),
#  np.str_('h148_12'),
#  np.str_('h148_23'),
#  np.str_('h148_27'),
#  np.str_('h148_34'),
#  np.str_('h148_38'),
#  np.str_('h148_55'),
#  np.str_('h148_65'),
#  np.str_('h148_249'),
#  np.str_('h148_251'),
#  np.str_('h148_282')]

# %%
Hchars_path = '/home/vadilloj/MAP2023/Vadillo-Justice-League-Code/All_halo_charachteristics.csv'
HChars = pd.read_csv(Hchars_path, index_col = 0)
HChars
# Out:
#                time         mstar          mgas          mass          Rvir  \
# key
# h148_2    13.800797  2.268773e+09  8.252345e+09  9.575866e+10     95.462198
# h148_3          NaN  1.502171e+09  2.975036e+09  4.697010e+10     76.483584
# h148_4    13.800797  4.317847e+08  9.706413e+08  3.248971e+10     67.335904
# h148_6    13.800797  3.315968e+08  1.010160e+09  2.869601e+10     64.716224
# h148_10   13.800797  1.353274e+08  1.139460e+09  1.055766e+10     46.469675
# h148_12   13.800797  1.043767e+08  7.503453e+06  9.071870e+09     43.979036
# h148_27   13.800797  8.415728e+07  1.026774e+08  3.249352e+09     31.367917
# h148_34   13.800797  5.759679e+06  5.869542e+07  2.628660e+09     29.130301
# h148_38   13.800797  1.374093e+07  0.000000e+00  1.883522e+09     26.060232
# h148_55   13.800797  2.822993e+06  5.263210e+06  1.361924e+09     23.525588
# h148_65   13.800797  3.001293e+07  0.000000e+00  8.996108e+08     20.341280
# ...

# %%
tracking.find_halo_keys(simulations)
# Out:
# ()

# %%
# Out:
#        gal num                                           filepath  \
# Sandra    h148  /home/vadilloj/MAP2023/Sims/h148.cosmo50PLK.30...
# Ruth      h229  /home/vadilloj/MAP2023/Sims/h229.cosmo50PLK.30...
# Sonia     h242  /home/vadilloj/MAP2023/Sims/h242.cosmo50PLK.30...
# Elena     h329  /home/vadilloj/MAP2023/Sims/h329.cosmo50PLK.30...
#
#                                                 Halo keys          mass  \
# Sandra  [h148_2, h148_3, h148_4, h148_6, h148_7, h148_...  2.052077e+12
# Ruth        [h229_14, h229_18, h229_20, h229_22, h229_49]  1.052426e+12
# Sonia   [h242_8, h242_10, h242_21, h242_30, h242_38, h...  1.150238e+12
# Elena                         [h329_7, h329_29, h329_117]  7.104449e+11
#
#                mstar          mgas        Rvir  nSats       HI_mass  \
# Sandra  1.917510e+11  1.527100e+11  266.215150   16.0  1.414185e+10
# Ruth    1.020237e+11  7.695528e+10  214.442995    5.0  1.862303e+10
# ...
